# %%
#1. Business Problem: A car rental company wants to analyze the rental durations of itscustomers to understand the typical rental period and optimize its pricing andfleet
#management strategies. Data: Let's consider the rental durations (in days) for asample of 50 customers:
#3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5
#Question:
#a. Mean: What is the average rental duration for customers at the car rental company?
#b. Median: What is the typical or central rental duration experiencedbycustomers?
#c. Mode: Are there any recurring or most frequently occurring rental durations for customers?

import numpy as np
import statistics

rental_duration_days=[3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5]
mean=np.mean(rental_duration_days)
median=np.median(rental_duration_days)
mode=statistics.mode(rental_duration_days)

print("Mean:",mean)
print("Median:",median)
print("Mode",mode)
# Out:
# Mean: 3.44
# Median: 3.0
# Mode 2

# %%
#2. An e-commerce platform wants to analyze the delivery times of its shipments tounderstand the variability in order fulfillment and optimize its logistics operations. Data:
#Let's consider the delivery times (in days) for a sample of 50 shipments:
#3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5, 3
#Questions:
#a. Range: What is the range of the delivery times?
#b. Variance: What is the variance of the delivery times?
#c. Standard Deviation: What is the standard deviation of the deliverytimes?


import statistics

days=[3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5, 3]
range= max(days)-min(days)
variance=statistics.variance(days)
std= statistics.stdev(days)

print("Range:",range)
print("Variance:",variance)
print("Standard deviation:",std)
# Out:
# Range: 6
# Variance: 2.336326530612245
# Standard deviation: 1.528504671439458

# %%
#3. A company wants to analyze the monthly revenue generated by one of its productsto understand its performance and variability. Data: Let's consider the monthly revenue (in thousands of dollars) for the past 12months:
#$120, $150, $110, $135, $125, $140, $130, $155, $115, $145, $135, $130Questions:
#a. Measure of Central Tendency: What is the average monthly revenuefor the product?
#b. Measure of Dispersion: What is the range of monthly revenue for the product?

import numpy as np

revenue=[120, 150, 110, 135, 125, 140, 130, 155, 115, 145, 135, 130]
mean=np.mean(revenue)
range=max(revenue)-min(revenue)

print("Mean:",mean)
print("Range:",range)
# Out:
# Mean: 132.5
# Range: 45

# %%
#4. A transportation company wants to analyze the fuel efficiency of its vehicle fleet toidentify any variations across different vehicle models. Data: Let's consider the fuel efficiency (in miles per gallon, mpg) for a sampleof50 vehicles:
#Model A: 30, 32, 33, 28, 31, 30, 29, 30, 32, 31, Model B: 25, 27, 26, 23, 28, 24, 26, 25, 27, 28, Model C: 22, 23, 20, 25, 21, 24, 23, 22, 25, 24, Model D: 18, 17, 19, 20, 21, 18, 19, 17, 20, 19, Model E: 35, 36, 34, 35, 33, 34, 32, 33, 36, 34
#Questions:
#a. Measure of Central Tendency: What is the average fuel efficiencyfor eachvehicle model?
#b. Measure of Dispersion: What is the range of fuel efficiency for eachvehicle model?
#c. Measure of Dispersion: What is the variance of the fuel efficiencyfor eachvehicle model?

import numpy as np
from scipy import stats

model_a=[30, 32, 33, 28, 31, 30, 29, 30, 32, 31]
model_b=[25, 27, 26, 23, 28, 24, 26, 25, 27, 28]
model_c=[22, 23, 20, 25, 21, 24, 23, 22, 25, 24]
model_d=[18, 17, 19, 20, 21, 18, 19, 17, 20, 19]
model_e=[35, 36, 34, 35, 33, 34, 32, 33, 36, 34]

# A
print("Average fuel efficiency for each vehicle model:")
print("Model A :",np.mean(model_a))
print("Model B :",np.mean(model_b))
print("Model C :",np.mean(model_c))
print("Model D :",np.mean(model_d))
print("Model E :",np.mean(model_e))

print()
print()

# B
print("Range of fuel efficiency for each vehicle model:")
print("A :",max(model_a) - min(model_a))
print("B :",max(model_b) - min(model_b))
print("C :",max(model_c) - min(model_c))
print("D :",max(model_d) - min(model_d))
print("E :",max(model_e) - min(model_e))

print()
print()

# C
print("Variance of the fuel efficiency for each vehicle model:")
print("Variance of Model A :",np.var(model_a))
print("Variance of Model B :",np.var(model_b))
print("Variance of Model C :",np.var(model_c))
print("Variance of Model D :",np.var(model_d))
print("Variance of Model E :",np.var(model_e))
# Out:
# Average fuel efficiency for each vehicle model:
# Model A : 30.6
# Model B : 25.9
# Model C : 22.9
# Model D : 18.8
# Model E : 34.2
#
#
# Range of fuel efficiency for each vehicle model:
# A : 5
# B : 5
# C : 5
# D : 4
# E : 4
#
#
# Variance of the fuel efficiency for each vehicle model:
# Variance of Model A : 2.0400000000000005
# Variance of Model B : 2.49
# Variance of Model C : 2.4899999999999998
# Variance of Model D : 1.56
# Variance of Model E : 1.5599999999999998

# %%
#5  5. A manufacturing company wants to analyze the defect rates of its productionlinetoidentify the frequency of different types of defects. Data: Let's consider the types of defects and their corresponding frequencies
#observed in a sample of 200 products:
#Defect Type: A, B, C, D, E, F, G
#Frequency: 30, 40, 20, 10, 45, 25, 30
#Questions:
#a. Bar Chart: Create a bar chart to visualize the frequency of different defect types.
#b. Most Common Defect: Which defect type has the highest frequency?
#c. Histogram: Create a histogram to represent the defect frequencies.



import matplotlib.pyplot as plt
import seaborn as sns

defect_type =['A','B','C','D','E','F','G']
frequency=[30,40,20,10,45,25,30]

# A
plt.figure(figsize=(8,5))
sns.barplot(x=defect_type, y=frequency, palette='Set2')
plt.title("Frequenct of different defect types")
plt.xlabel("Defect Type")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# B
# Most common defect
max_freq = max(frequency)
most_common_index = frequency.index(max_freq)
most_common_defect = defect_type[most_common_index]

print(f"Most common defect type: {most_common_defect} (Frequency: {max_freq})")


# C
plt.figure(figsize=(8,5))
sns.histplot(frequency,bins=7,kde=False, color='skyblue', edgecolor='black')
plt.title("Distribution of defect frequency")
plt.xlabel("Frequency Range")
plt.ylabel("Number of Defect types")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_12420\1510263504.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=defect_type, y=frequency, palette='Set2')
# Most common defect type: E (Frequency: 45)

# %%
#6. A survey was conducted to analyze the satisfaction ratings of customers onascaleof 1 to 5 for a specific product. Data: Let's consider the satisfaction ratings from 200 customers:
#Ratings:4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3, 4, 3, 2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4
#Questions:
#a. Skewness: Calculate the skewness of the satisfaction ratings.
#b. Kurtosis: Calculate the kurtosis of the satisfaction ratings.
#c. Interpretation: Based on the skewness and kurtosis values, what can be inferred about the satisfaction ratings distribution?

from scipy import stats

ratings=[4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3, 4, 3, 2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4]
print("Skweness:",stats.skew(ratings))
print("Kurtosis:",stats.kurtosis(ratings))

print("The distribution of satisfaction ratings is slightly left-skewed, indicating that most customers are satisfied (rating 4–5)")
print("The negative kurtosis suggests a flatter distribution, meaning the ratings are fairly consistent and not concentrated at a single point.")
# Out:
# Skweness: -0.20773281879682218
# Kurtosis: -0.767917404014467
# The distribution of satisfaction ratings is slightly left-skewed, indicating that most customers are satisfied (rating 4–5)
# The negative kurtosis suggests a flatter distribution, meaning the ratings are fairly consistent and not concentrated at a single point.

# %%
#7. A research study wants to analyze the weight distribution of a sample of
#individuals to assess their health and body composition.
#Data: Let's consider the weights (in kilograms) of a sample of 100 individuals:
#Weights:
#55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95, 100, 105, 110, 115,
#120, 125, 130, 135, 140, 145, 150, 155, 160, 165, 170, 175, 180, 185, 190, 195,
#200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275,
#280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340, 345, 350, 355,
#360, 365, 370, 375, 380, 385, 390, 395, 400, 405, 410, 415, 420, 425, 430, 435,
#440, 445, 450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515
#Questions:
#a. Quartiles: Calculate the first quartile (Q1), median (Q2), and third quartile
#(Q3) of the weight distribution.
#b. Percentiles: Calculate the 15th percentile, 50th percentile, and 85th
#percentile of the weight distribution.
#c. Interpretation: Based on the quartiles and percentiles, what can be inferred
#about the weight distribution of the individuals?
#By answering these questions using quartiles and percentiles, the research study
#can understand the weight distribution and identify the weight ranges at different
#percentiles, such as underweight, normal weight, overweight, and obese categories.


import numpy as np
from scipy import stats
weights=[
55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95, 100, 105, 110, 115,
120, 125, 130, 135, 140, 145, 150, 155, 160, 165, 170, 175, 180, 185, 190, 195,
200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275,
280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340, 345, 350, 355,
360, 365, 370, 375, 380, 385, 390, 395, 400, 405, 410, 415, 420, 425, 430, 435,
440, 445, 450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515]

#a
print("Q1:",np.percentile(weights,25))
print("Q2:",np.percentile(weights,50))
print("Q3:",np.percentile(weights,75))
print()
#b
print("15th percentile:",np.percentile(weights,15))
print("50th percentile:",np.percentile(weights,50))
print("85th percentile:",np.percentile(weights,85))
# Out:
# Q1: 143.75
# Q2: 267.5
# Q3: 391.25
#
# 15th percentile: 94.55
# 50th percentile: 267.5
# 85th percentile: 440.74999999999994

# %%
#8. A researcher wants to examine the relationship between the hours spent studying and the exam scores of a group of students. Data: Let's consider the number of hours spent studying and the corresponding exam scores for a sample of 30 students:
#Hours Spent Studying: 10, 12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82
#Exam Scores: 60, 65, 70, 75, 80, 82, 85, 88, 90, 92, 93, 95, 96, 97, 98, 99, 100, 102, 105, 106, 107, 108, 110, 112, 114, 115, 116, 118, 120, 122
#Question: Calculate the correlation coefficient between the hours spent studying and the exam scores. Interpret the value of the correlation coefficient and explain the nature of the relationship between studying hours and exam scores.
#By analyzing the correlation coefficient, the researcher can determine the strength and direction of the relationship between studying hours and exam scores. This information can provide insights into the effectiveness of studying and help students and educators make informed decisions about study habits and academic performance.

import numpy as np

hours=[ 10, 12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82]
scores=[60, 65, 70, 75, 80, 82, 85, 88, 90, 92, 93, 95, 96, 97, 98, 99, 100, 102, 105, 106, 107, 108, 110, 112, 114, 115, 116, 118, 120, 122]

corr=np.corrcoef(hours,scores)[0,1]
print("Correlation Coefficient:",corr)

print("Since r ≈ 0.997, there is a very strong positive correlation between hours spent studying and exam scores.")
print("As hours spent studying increase, exam scores also increase.")
# Out:
# Correlation Coefficient: 0.9772950830186736
# Since r ≈ 0.997, there is a very strong positive correlation between hours spent studying and exam scores.
# As hours spent studying increase, exam scores also increase.

# %%
#9. A multiple-choice test consists of 10 questions, each with four possible answers. If a
#student randomly guesses on each question, what is the probability of getting at least
#8 questions correct? Data: Number of questions (n) = 10, Number of possible answers per question (k) = 4

from scipy.stats import binom
n=10
p=0.25
x=[8,9,10]

probability_at_least_8=sum(binom.pmf(x,n,p))
print("Probability of getting at least 8 questions correct answer:",probability_at_least_8)
# Out:
# Probability of getting at least 8 questions correct answer: 0.0004158020019531251

# %%
#10. The lifetimes of a certain brand of light bulbs are normally distributed with a mean
#of 1000 hours and a standard deviation of 100 hours. What is the probability that a
#randomly selected light bulb lasts between 900 and 1100 hours? Data: Mean lifetime
#(μ) = 1000 hours, Standard deviation (σ) = 100 hours, Lifetime range (lower limit x1,upper limit x2)

from scipy.stats import norm

mu=1000
std=100

probabiltiy_light_bulb=norm.cdf(1100,mu,std)-norm.cdf(900,mu,std)
print("Probability of a randomly selected light bulb lasts between 900 and 1100 hours is :",probabiltiy_light_bulb)
# Out:
# Probability of a randomly selected light bulb lasts between 900 and 1100 hours is : 0.6826894921370859

# %%
#11. A study is conducted to estimate the mean height of a population. A random sample
#of 100 individuals is selected, and their heights are measured. Calculate a 95%
#confidence interval for the population mean height, given that the sample mean
#height is 170 cm and the sample standard deviation is 8 cm. Data: Sample size (n) =
#100, Sample mean (x̄) = 170 cm, Sample standard deviation (s) = 8 cm, Confidence level = 95%


import scipy.stats as stats
import math

n = 100
s_mean = 170
s = 8
confidence_level = 0.95

standard_error = s / math.sqrt(n)

z_score = stats.norm.ppf((1 + confidence_level) / 2)

margin_of_error = z_score * standard_error

lower_bound = s_mean - margin_of_error
upper_bound = s_mean + margin_of_error


print("95% Confidence Interval for the population mean height:")
print(f"({lower_bound:.2f} cm, {upper_bound:.2f} cm)")
print(f"Margin of Error: {margin_of_error:.2f} cm")
print(f"Z-score : {z_score:.2f}")
print(f"Standard Error: {standard_error:.2f}")
# Out:
# 95% Confidence Interval for the population mean height:
# (168.43 cm, 171.57 cm)
# Margin of Error: 1.57 cm
# Z-score : 1.96
# Standard Error: 0.80

# %%
#12. A manufacturing company claims that the average weight of its product is 500 grams. To test this claim, a random sample of 25 products is selected, and their weights are measured. The sample mean weight is found to be 510 grams with a sample standard deviation of 20 grams. Perform a hypothesis test to determine if there is evidence to support the company's claim.
#Data: Sample size (n) = 25, Sample mean (x̄) = 510 grams, Sample standard deviation (s) = 20 grams, Population mean (μ) = 500 grams
#Explanation: In this problem, we are conducting a hypothesis test to assess whether the sample mean weight provides evidence to support the company's claim about the population mean weight. The null hypothesis (H0) assumes that the population mean weight is equal to the claimed value, while the alternative hypothesis (Ha) suggests otherwise

import numpy as np
from scipy import stats
p_mean = 500
s_mean = 510
n = 25
s = 20
num = s_mean - p_mean
den = s/n**0.5
t_score = num/den
df = n-1
p = stats.t.sf(np.abs(t_score),df)*2
print(f"P value is:{p}")
if p <0.05:
    print("Rejecting H0")
else:
    print("Accepting H0")
# Out:
# P value is:0.019654175116578753
# Rejecting H0

# %%
# 13. A researcher wants to test whether a new teaching method improves student performance. A random sample of 50 students is divided into two groups: one group taught using the new method and the other using the traditional method. The average test scores of the two groups are compared. State the null and alternative hypotheses for this study. Data: Sample size (n) = 50, Test scores of the two groups
#Explanation: In this problem, we are interested in comparing the means of two groups (new method vs. traditional method).
#The null hypothesis (H0) states that there is no significant difference between the means, while the alternative hypothesis (Ha) suggests that there is a significant difference

n = 50
print("Null hypothesis tells that there is no change in teaching method whereas the alternate hypothesis will state that there is a difference in new method and traditional method.")
# Out:
# Null hypothesis tells that there is no change in teaching method whereas the alternate hypothesis will state that there is a difference in new method and traditional method.

# %%
#14. A survey is conducted to estimate the proportion of people in a city who support a particular policy. A random sample of 500 individuals is surveyed, and 320 of them express support for the policy. Calculate a 90% confidence interval for the population proportion, given the sample proportion.
#Data: Sample size (n) = 500, Number of successes (x) = 320, Confidence level = 90%
#Explanation: In this problem, we aim to estimate the population proportion based on the sample proportion. By constructing a confidence interval, we provide a range of plausible values for the population proportion. The 90% confidence level indicates that we are 90% confident that the true population proportion falls within the calculated interval.

import math
from scipy.stats import norm

n = 500
x = 320
confidence = 0.90

#sample proportion
s_prop = x / n

z = norm.ppf(1 - (1 - confidence) / 2)

SE = math.sqrt((s_prop * (1 - s_prop)) / n)

ME = z * SE

lower = s_prop - ME
upper = s_prop + ME

print(f"Sample proportion (p̂): {s_prop:.3f}")
print(f"Z-value: {z:.3f}")
print(f"Standard Error: {SE:.5f}")
print(f"Margin of Error: {ME:.3f}")
print(f"90% Confidence Interval: ({lower:.3f}, {upper:.3f})")
# Out:
# Sample proportion (p̂): 0.640
# Z-value: 1.645
# Standard Error: 0.02147
# Margin of Error: 0.035
# 90% Confidence Interval: (0.605, 0.675)

# %%
#15. A company sells smartphones, and the number of defects per batch follows a
#Poisson distribution with a mean of 2 defects. What is the probability of having
#exactly 3 defects in a randomly selected batch? Data: Mean number of defects (λ) =2, Number of defects (x) = 3

from scipy.stats import poisson

lambda_=2
x=3

probability_poisson=poisson.pmf(x,lambda_)
print(f"Probability of having exactly 3 defects in a randomly selected batch: {probability_poisson}")
# Out:
# Probability of having exactly 3 defects in a randomly selected batch: 0.18044704431548356
